# %%
import time

import numpy

import pandas
import sqlite3
import ciso8601


def get_df():
    conn = sqlite3.connect("bitmex.db")
    c = conn.cursor()

    s = time.perf_counter()
    symbol = 'XBTUSD'
    count = 100000
    c.execute("SELECT * FROM tradebin1m"
              " ORDER BY timestamp"
              " LIMIT ?"
              " OFFSET (SELECT COUNT(*) FROM tradebin1m) - ?"
              , [count, count]
              )
    print('execute : ', (time.perf_counter() - s) / 1_000_000)

    s = time.perf_counter()
    d = c.fetchall()
    print('fetchall : ', (time.perf_counter() - s) / 1_000_000)

    ts = [ciso8601.parse_datetime(item[1]) for item in d]
    close = [item[6] for item in d]
    
    df = pandas.DataFrame({'close': close}, index=ts)
    return df

df = get_df()
# Out:
# execute :  5.2728883980307726e-08
# fetchall :  4.0735460503492505e-07

# %%
import matplotlib
# %matplotlib inline
df['close'][-100:].plot()

# %%
import talib

# %%
talib.RSI?

# %%
df['rsi'] = talib.RSI(df['close'].values)

# %%
df[-500:].plot(y='rsi')

# %%
df['close_shift'] = df['close'] - df['close'].shift()
df['rsi_shift'] = df['rsi'] - df['rsi'].shift()

# %%
df
# Out:
#                             close        rsi  close_shift     rsi_shift
# 2018-06-24 05:49:00+00:00  5891.5        NaN          NaN           NaN
# 2018-06-24 05:50:00+00:00  5894.0        NaN          2.5           NaN
# 2018-06-24 05:51:00+00:00  5889.0        NaN         -5.0           NaN
# 2018-06-24 05:52:00+00:00  5892.0        NaN          3.0           NaN
# 2018-06-24 05:53:00+00:00  5890.5        NaN         -1.5           NaN
# 2018-06-24 05:54:00+00:00  5886.0        NaN         -4.5           NaN
# 2018-06-24 05:55:00+00:00  5890.0        NaN          4.0           NaN
# 2018-06-24 05:56:00+00:00  5892.5        NaN          2.5           NaN
# 2018-06-24 05:57:00+00:00  5896.5        NaN          4.0           NaN
# 2018-06-24 05:58:00+00:00  5896.5        NaN          0.0           NaN
# 2018-06-24 05:59:00+00:00  5892.0        NaN         -4.5           NaN
# 2018-06-24 06:00:00+00:00  5894.5        NaN          2.5           NaN
# 2018-06-24 06:01:00+00:00  5892.5        NaN         -2.0           NaN
# 2018-06-24 06:02:00+00:00  5884.5        NaN         -8.0           NaN
# 2018-06-24 06:03:00+00:00  5880.0  38.144330         -4.5           NaN
# 2018-06-24 06:04:00+00:00  5879.5  37.725490         -0.5 -4.188397e-01
# 2018-06-24 06:05:00+00:00  5886.0  46.023114          6.5  8.297623e+00
# 2018-06-24 06:06:00+00:00  5885.5  45.520663         -0.5 -5.024505e-01
# 2018-06-24 06:07:00+00:00  5887.0  47.376761          1.5  1.856098e+00
# 2018-06-24 06:08:00+00:00  5878.0  38.828858         -9.0 -8.547903e+00
# 2018-06-24 06:09:00+00:00  5879.0  40.121585          1.0  1.292727e+00
# 2018-06-24 06:10:00+00:00  5875.0  36.773901         -4.0 -3.347684e+00
# 2018-06-24 06:11:00+00:00  5867.0  31.171887         -8.0 -5.602014e+00
# 2018-06-24 06:12:00+00:00  5852.0  23.838955        -15.0 -7.332932e+00
# 2018-06-24 06:13:00+00:00  5860.5  33.399919          8.5  9.560963e+00
# 2018-06-24 06:14:00+00:00  5863.0  35.946838          2.5  2.546919e+00
# 2018-06-24 06:15:00+00:00  5844.0  27.377723        -19.0 -8.569114e+00
# 2018-06-24 06:16:00+00:00  5858.5  39.274869         14.5  1.189715e+01
# 2018-06-24 06:17:00+00:00  5865.0  43.725434          6.5  4.450565e+00
# 2018-06-24 06:18:00+00:00  5879.5  52.150337         14.5  8.424903e+00
# ...                           ...        ...          ...           ...
# 2018-09-01 15:59:00+00:00  7181.0  54.846733          5.0  8.842716e+00
# 2018-09-01 16:00:00+00:00  7175.0  45.266664         -6.0 -9.580069e+00
# 2018-09-01 16:01:00+00:00  7174.0  43.890648         -1.0 -1.376015e+00
# 2018-09-01 16:02:00+00:00  7174.0  43.890648          0.0 -7.105427e-15
# 2018-09-01 16:03:00+00:00  7178.0  50.825177          4.0  6.934529e+00
# 2018-09-01 16:04:00+00:00  7177.5  49.993434         -0.5 -8.317435e-01
# 2018-09-01 16:05:00+00:00  7178.0  50.859468          0.5  8.660342e-01
# 2018-09-01 16:06:00+00:00  7181.5  56.534120          3.5  5.674652e+00
# 2018-09-01 16:07:00+00:00  7186.5  63.091269          5.0  6.557150e+00
# 2018-09-01 16:08:00+00:00  7190.0  66.860053          3.5  3.768783e+00
# 2018-09-01 16:09:00+00:00  7192.0  68.819365          2.0  1.959312e+00
# 2018-09-01 16:10:00+00:00  7190.0  64.699906         -2.0 -4.119459e+00
# 2018-09-01 16:11:00+00:00  7191.5  66.327874          1.5  1.627968e+00
# 2018-09-01 16:12:00+00:00  7191.5  66.327874          0.0  0.000000e+00
# 2018-09-01 16:13:00+00:00  7192.0  66.917687          0.5  5.898127e-01
# 2018-09-01 16:14:00+00:00  7193.5  68.689584          1.5  1.771896e+00
# 2018-09-01 16:15:00+00:00  7214.5  82.677727         21.0  1.398814e+01
# 2018-09-01 16:16:00+00:00  7208.5  72.686039         -6.0 -9.991688e+00
# 2018-09-01 16:17:00+00:00  7212.0  74.613372          3.5  1.927333e+00
# 2018-09-01 16:18:00+00:00  7213.5  75.414066          1.5  8.006943e-01
# 2018-09-01 16:19:00+00:00  7217.0  77.219519          3.5  1.805453e+00
# 2018-09-01 16:20:00+00:00  7211.0  68.000600         -6.0 -9.218919e+00
# 2018-09-01 16:21:00+00:00  7210.5  67.279756         -0.5 -7.208431e-01
# 2018-09-01 16:22:00+00:00  7203.5  58.008614         -7.0 -9.271142e+00
# 2018-09-01 16:23:00+00:00  7196.0  50.050579         -7.5 -7.958035e+00
# 2018-09-01 16:24:00+00:00  7199.0  52.837683          3.0  2.787104e+00
# 2018-09-01 16:25:00+00:00  7202.0  55.511056          3.0  2.673373e+00
# 2018-09-01 16:26:00+00:00  7199.0  52.317351         -3.0 -3.193705e+00
# 2018-09-01 16:27:00+00:00  7202.5  55.531729          3.5  3.214378e+00
# 2018-09-01 16:28:00+00:00  7208.5  60.453411          6.0  4.921682e+00
#
# [100000 rows x 4 columns]

# %%
df['ratio'] = df['close_shift']/df['rsi_shift']

# %%
length = 1000
df[-length:].plot(y='ratio')
df[-length:].plot(y='close')

# %%
upper, middle, lower = talib.BBANDS(df['close'].values, timeperiod=20)
bbr = (df['close'] - lower) / (upper - lower)

# %%
bbr = pandas.DataFrame()
close = df['close'].values
for minute in range(20, 5000, 20):
    period = minute
    upper, middle, lower = talib.BBANDS(close, timeperiod=period)
    bbr[str(period)] = (close - lower) / (upper - lower)
# Out:
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide
#
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %%
bbr.tail()
# Out:
#              20        40        60        80       100       120       140  \
# 99995  0.508700  0.704163  0.769681  0.824975  0.679647  0.712655  0.748529
# 99996  0.552432  0.748491  0.824116  0.881296  0.695760  0.722294  0.756626
# 99997  0.456474  0.683549  0.751426  0.807819  0.675078  0.706179  0.741462
# 99998  0.528292  0.736148  0.815134  0.876231  0.696679  0.718427  0.751632
# 99999  0.673717  0.828489  0.923303  0.992240  0.738011  0.741916  0.771393
#
#             160       180       200    ...         4800      4820      4840  \
# 99995  0.780242  0.808735  0.835157    ...     1.196973  1.197012  1.196606
# 99996  0.787896  0.816188  0.842474    ...     1.206628  1.206664  1.206287
# 99997  0.773228  0.801690  0.827860    ...     1.195719  1.195725  1.195370
# 99998  0.782877  0.811062  0.837062    ...     1.207077  1.207072  1.206761
# 99999  0.801677  0.829365  0.855136    ...     1.226959  1.226929  1.226668
#
#            4860      4880      4900      4920      4940      4960      4980
# 99995  1.196078  1.195851  1.195782  1.195142  1.194379  1.194076  1.194028
# 99996  1.205768  1.205542  1.205483  1.204888  1.204117  1.203802  1.203765
# 99997  1.194848  1.194606  1.194536  1.193976  1.193196  1.192850  1.192802
# 99998  1.206241  1.206002  1.205931  1.205426  1.204646  1.204282  1.204254
# 99999  1.226159  1.225929  1.225865  1.225420  1.224639  1.224265  1.224265
#
# [5 rows x 249 columns]

# %%
import talib.stream

upper, middle, lower = talib.stream.BBANDS(df['close'].values, timeperiod=minute)
(upper, middle, lower)
# Out:
# (7143.405259262145, 6998.27640562249, 6853.147551982835)

# %%
import talib.stream

def test():
    a = []
    close = df['close'].values
    for minute in range(5, 2000):
        upper, middle, lower = talib.stream.BBANDS(close, timeperiod=minute)
        a.append((close[-1] - lower) / (upper - lower))
    
    return a

# %timeit test()
# Out:
# 6.86 ms ± 547 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df['close'][-100:].plot()
bbr[-100:].plot(legend=False, colormap='hot')

# %%
length = 400
ax = bbr[-length:].T.plot(colormap="YlOrRd", legend=False)
ax.axhline(y=0, color='b')

# %%
pandas.Series(talib.RSI(df['close'].values))[-100:].plot()

# %%
length = 1000
rsi = pandas.DataFrame()
for i in range(10, 100):
    rsi[str(i)] = talib.RSI(df['close'].values, timeperiod=i)


df['close'][-length:].plot()
rsi[-length:].plot(colormap='hot', legend=False)
bbr[-length:].plot(colormap='hot', legend=False)

# %%
rsi['10'][10]
# Out:
# 50.79365079365079

# %%
for i in range(10):
    print(df.close[i], rsi.loc[i].max(), bbr.loc[i].max())
# Out:
# 5891.5 nan nan
# 5894.0 nan nan
# 5889.0 nan nan
# 5892.0 nan nan
# 5890.5 nan nan
# 5886.0 nan nan
# 5890.0 nan nan
# 5892.5 nan nan
# 5896.5 nan nan
# 5896.5 nan nan

# %%
rsi.loc[100].idxmax(), rsi.loc[100].max()
# Out:
# ('10', 66.40383385260559)

# %%
def get_ratio(before, after):
    return 1 + (after - before) / before

get_ratio(100, 25)
# Out:
# 0.25

# %%
money = 100

order = []
for i in range(len(df.close)):
    _rsi = rsi['10'][i]
    price = df.close[i]
    
    if pandas.isna(_rsi):
        order.append((money, None, None, None, None, None))
        continue
    
    last_order = order[-1]
    last_money = last_order[0]
    last_pos = last_order[1]
    last_price = df.close[i-1]
    
    ratio = get_ratio(last_price, price)
    
    if _rsi < 20:
        
        if last_pos == None:
            order.append((last_money, 'buy', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), 'buy_sig'))
        else:
            order.append((last_money * ratio, last_pos, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
        
    elif _rsi > 90:
        
        if last_pos == 'buy':
            order.append((last_money * ratio, 'sell', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), 'sell_sig'))
        else:
            order.append((last_money, None, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
    
    else:
        if last_pos == 'buy':
            order.append((last_money * ratio, 'buy', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
        else:
            order.append((last_money, None, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))

# %%
money = [tup[0] for tup in order]
pos = [tup[1] for tup in order]
r = [tup[2] for tup in order]
r_max = [tup[3] for tup in order]
r_min = [tup[4] for tup in order]
sig = [tup[5] for tup in order]

len(money), len(pos), len(r)
backt = pandas.DataFrame({'money': money, 'pos': pos, 'r': r, 'r_max': r_max, 'r_min': r_min, 'sig': sig})

# %%
backt[:100]
# Out:
#          money   pos          r r_max r_min      sig
# 0   100.000000  None        NaN  None  None     None
# 1   100.000000  None        NaN  None  None     None
# 2   100.000000  None        NaN  None  None     None
# 3   100.000000  None        NaN  None  None     None
# 4   100.000000  None        NaN  None  None     None
# 5   100.000000  None        NaN  None  None     None
# 6   100.000000  None        NaN  None  None     None
# 7   100.000000  None        NaN  None  None     None
# 8   100.000000  None        NaN  None  None     None
# 9   100.000000  None        NaN  None  None     None
# 10  100.000000  None  50.793651    10    10     None
# 11  100.000000  None  54.781199    10    11     None
# 12  100.000000  None  51.100286    12    10     None
# 13  100.000000  None  39.349210    13    10     None
# 14  100.000000  None  34.404413    14    10     None
# 15  100.000000  None  33.878813    15    10     None
# 16  100.000000  None  45.832031    13    16     None
# 17  100.000000  None  45.134653    13    16     None
# 18  100.000000  None  47.783088    13    18     None
# 19  100.000000  None  36.149733    19    10     None
# 20  100.000000  None  38.012880    19    10     None
# 21  100.000000  None  33.648988    21    10     None
# 22  100.000000  None  26.809553    22    10     None
# 23  100.000000   buy  18.834145    23    10  buy_sig
# 24  100.145249   buy  31.638559    22    10     None
# 25  100.187970   buy  34.990099    22    10     None
# 26   99.863295   buy  24.745407    26    10     None
# 27  100.111073   buy  39.712926    10    27     None
# 28  100.222146   buy  45.146938    10    28     None
# 29  100.469925   buy  55.163905    10    29     None
# ..         ...   ...        ...   ...   ...      ...
# 70  100.264867   buy  59.054525    10    67     None
# 71  100.410116   buy  65.468665    10    71     None
# 72  100.461381   buy  67.467209    10    72     None
# 73  100.487013   buy  68.480665    10    73     None
# 74  100.487013   buy  68.480665    10    74     None
# 75  100.563910   buy  71.741096    10    75     None
# 76  100.794600   buy  78.986656    10    76     None
# 77  100.692071   buy  70.109597    10    76     None
# 78  100.572454   buy  61.194394    11    76     None
# 79  100.410116   buy  51.348320    17    71     None
# 80  100.375940   buy  49.485821    19    71     None
# 81  100.341763   buy  47.568703    20    10     None
# 82  100.350308   buy  48.126926    20    71     None
# 83  100.239234   buy  41.712167    25    10     None
# 84  100.222146   buy  40.782954    26    10     None
# 85  100.247779   buy  42.902854    24    10     None
# 86  100.299043   buy  47.110379    22    10     None
# 87  100.273411   buy  45.257569    23    10     None
# 88  100.256323   buy  43.976417    24    10     None
# 89  100.119617   buy  35.135410    37    10     None
# 90  100.162338   buy  39.367864    32    10     None
# 91  100.299043   buy  50.785691    19    71     None
# 92  100.179426   buy  42.926596    31    10     None
# 93  100.059809   buy  36.628517    93    10     None
# 94  100.068353   buy  37.357936    93    10     None
# 95  100.128161   buy  42.505101    34    10     None
# 96  100.111073   buy  41.424541    36    10     None
# 97  100.469925   buy  63.233571    10    97     None
# 98  100.521189   buy  65.285182    10    98     None
# 99  100.529733   buy  65.640240    10    99     None
#
# [100 rows x 6 columns]

# %%
(
    len(backt[backt['pos'] == 'sell']),
    len(backt[backt['sig'] == 'buy_sig']), 
    len(backt[backt['sig'] == 'sell_sig']), 
    len(backt[backt['pos'] == 'buy']), 
    len(backt)
)
# Out:
# (160, 160, 160, 78658, 100000)

# %%
backt['money'].plot()

# %%
df['close'].plot()

# %%
backt['r_max'] = backt.r_max.fillna(0).astype(int)
backt['r_min'] = backt.r_min.fillna(0).astype(int)

# %%
backt[-200:].plot(y=['r_min'])

# %%
backt[-200:].plot(y=['r_max'])

# %%
backt[-200:].plot(y=['r_max', 'r_min'])

# %%
df.close[-200:].plot()

# %%
((rsi['10'][-200:] - 20) / 60).plot()

# %%
start = 101
length = 100

bbr_half = bbr['20'] - 0.5
rsi_half = ((rsi['14'] - 20)/60) - 0.5

bbr_half[-start:-start+length].plot()
ax =  rsi_half[-start:-start+length].plot()
ax.axhline(y=0.5, color='r')
ax.axhline(y=-0.5, color='r')
ax.axhline(y=0, color='r')

# %%
ax = (bbr_half - rsi_half)[-start:-start+length].plot()
ax.axhline(y=0, color='r')

# %%
df.close[-start:-start+length].plot()

# %%
start = 600
length = 100
bbr.T.min()[-start:-start+length].plot()
bbr.T.max()[-start:-start+length].plot()

# %%
max_min = (bbr.T.max() - bbr.T.min())
ax = max_min[-start:-start+length].plot()
ax.axhline(y=1, color='r')

# %%
df['close'][-start:-start+length].plot()

# %%
(max_min[-start:-start+length] - max_min[-start:-start+length].shift()).plot()

# %% [markdown]
# BBW Count
# --------------

# %%
start = 2000
length = 1000
bbr[-start:-start+length].plot(colormap='hot')

# %%
start = 501
length = 500
df.close[-start:-start+length].plot()

# %%
bbr_max_id = bbr.T.idxmax().fillna(0).astype(int)
bbr_min_id = bbr.T.idxmin().fillna(0).astype(int)
bbr_max_id[-start:-start+length].plot()

# %%
bbr_max_id = bbr.T.idxmax().fillna(0).astype(int)
bbr_min_id = bbr.T.idxmin().fillna(0).astype(int)
bbr_max_id[-start:-start+length].plot()

# %%
bbr_min_id[-start:-start+length].plot()

# %%
bbr_min_id[-start:-start+length].plot()

# %%
ax = bbr[-10:].T.plot(colormap='GnBu', legend=False)
ax.axhline(y=0, color='r')
ax.axhline(y=1, color='r')

# %%
def get_bbr(r = range(20,5000,20)):
    bbr = pandas.DataFrame()
    close = df['close'].values
    for minute in r:
        period = minute
        upper, middle, lower = talib.BBANDS(close, timeperiod=period)
        bbr[str(period)] = (close - lower) / (upper - lower)
    return bbr

period = 1
minute = 20
four_times = 4 * 60 * (minute * period)
bbr = get_bbr(range(minute, four_times + 1, minute * period))
# Out:
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide
#
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide

# %%
bbr.head()
# Out:
#    20  40  60  80  100  120  140  160  180  200  ...   4620  4640  4660  4680  \
# 0 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
# 1 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
# 2 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
# 3 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
# 4 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
#
#    4700  4720  4740  4760  4780  4800
# 0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 240 columns]

# %%
df = get_df()
bbr = get_bbr(range(20, 10000, 40))
start = 1001
length = 1000
df.close[-start:-start+length].plot(figsize=(16, 16))
# Out:
# execute :  5.12673519551754e-08
# fetchall :  4.134331219829619e-07
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide
#
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide

# %%
bbr_max_id = bbr.T.idxmax().fillna(0).astype(int)
bbr_min_id = bbr.T.idxmin().fillna(0).astype(int)
df_bbr = pandas.DataFrame()
df_bbr['bbr_max'] = bbr_max_id[-start:-start+length]
df_bbr['bbr_min'] = bbr_min_id[-start:-start+length]
df_bbr.plot(figsize=(16,16), colormap='jet')

# %%
bbr['20'][-start:-start+length].plot(figsize=(16, 16), colormap='gray')

# %%
df_bbr.dtypes
# Out:
# bbr_max    int64
# bbr_min    int64
# dtype: object
