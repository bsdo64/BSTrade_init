# %%
import time

import numpy

import pandas
import sqlite3
import ciso8601

conn = sqlite3.connect("bitmex.db")
c = conn.cursor()

s = time.perf_counter()
symbol = 'XBTUSD'
count = 100000
c.execute("SELECT * FROM tradebin1m"
          " ORDER BY timestamp"
          " LIMIT ?"
          " OFFSET (SELECT COUNT(*) FROM tradebin1m) - ?"
          , [count, count]
          )
print('execute : ', (time.perf_counter() - s) / 1000_000)

s = time.perf_counter()
d = c.fetchall()
print('fetchall : ', (time.perf_counter() - s) / 1000_000)

conn.close()
# Out:
# execute :  5.954520497471094e-08
# fetchall :  4.4538237300002945e-07

# %%
ts = [ciso8601.parse_datetime(item[1]) for item in d]
close = [item[6] for item in d]

# %%
df = pandas.DataFrame({'close': close}, index=ts)

# %%
import matplotlib
# %matplotlib inline
df['close'][-100:].plot()

# %%
import talib

# %%
talib.RSI?

# %%
df['rsi'] = talib.RSI(df['close'].values)

# %%
df[-500:].plot(y='rsi')

# %%
df['close_shift'] = df['close'] - df['close'].shift()
df['rsi_shift'] = df['rsi'] - df['rsi'].shift()

# %%
df
# Out:
#                             close        rsi  close_shift     rsi_shift
# 2018-06-23 20:23:00+00:00  6134.5        NaN          NaN           NaN
# 2018-06-23 20:24:00+00:00  6132.0        NaN         -2.5           NaN
# 2018-06-23 20:25:00+00:00  6129.0        NaN         -3.0           NaN
# 2018-06-23 20:26:00+00:00  6127.5        NaN         -1.5           NaN
# 2018-06-23 20:27:00+00:00  6127.5        NaN          0.0           NaN
# 2018-06-23 20:28:00+00:00  6126.5        NaN         -1.0           NaN
# 2018-06-23 20:29:00+00:00  6126.5        NaN          0.0           NaN
# 2018-06-23 20:30:00+00:00  6126.5        NaN          0.0           NaN
# 2018-06-23 20:31:00+00:00  6138.5        NaN         12.0           NaN
# 2018-06-23 20:32:00+00:00  6137.0        NaN         -1.5           NaN
# 2018-06-23 20:33:00+00:00  6136.5        NaN         -0.5           NaN
# 2018-06-23 20:34:00+00:00  6136.5        NaN          0.0           NaN
# 2018-06-23 20:35:00+00:00  6137.0        NaN          0.5           NaN
# 2018-06-23 20:36:00+00:00  6136.5        NaN         -0.5           NaN
# 2018-06-23 20:37:00+00:00  6136.0  53.191489         -0.5           NaN
# 2018-06-23 20:38:00+00:00  6136.0  53.191489          0.0  0.000000e+00
# 2018-06-23 20:39:00+00:00  6136.0  53.191489          0.0  0.000000e+00
# 2018-06-23 20:40:00+00:00  6136.0  53.191489          0.0  0.000000e+00
# 2018-06-23 20:41:00+00:00  6136.5  54.493791          0.5  1.302301e+00
# 2018-06-23 20:42:00+00:00  6136.0  52.908543         -0.5 -1.585248e+00
# 2018-06-23 20:43:00+00:00  6136.0  52.908543          0.0  0.000000e+00
# 2018-06-23 20:44:00+00:00  6136.5  54.445463          0.5  1.536920e+00
# 2018-06-23 20:45:00+00:00  6141.0  65.392689          4.5  1.094723e+01
# 2018-06-23 20:46:00+00:00  6140.5  63.564876         -0.5 -1.827813e+00
per, middle, lower = talib.BBANDS(df['close'].values, timeperiod=20)
bbr = (df['close'] - lower) / (upper - lower)

# %%
bbr = pandas.DataFrame()
for minute in range(5, 2000):
    upper, middle, lower = talib.BBANDS(df['close'].values, timeperiod=minute)
    bbr[str(minute)] = (df['close'].values - lower) / (upper - lower)
# Out:
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
bbr.tail()
# Out:
#               5         6         7         8         9        10        11  \
# 99995  0.043565  0.000000 -0.041266  0.450654  0.537932  0.582303  0.612688
# 99996  0.205116  0.165923  0.130726  0.097958  0.453576  0.535944  0.578089
# 99997  0.295876  0.257464  0.223921  0.193814  0.165923  0.456034  0.534239
# 99998  0.241977  0.208501  0.169281  0.134218  0.102221  0.079916  0.389315
# 99999  0.625000  0.433185  0.379719  0.349384  0.323223  0.299967  0.275935
#
#              12        13        14    ...         1990      1991      1992  \
# 99995  0.637527  0.659526  0.678979    ...     0.802759  0.802886  0.803011
# 99996  0.606988  0.630620  0.651536    ...     0.802446  0.802572  0.802698
# 99997  0.574462  0.602075  0.624659    ...     0.802134  0.802258  0.802385
# 99998  0.487708  0.534189  0.563643    ...     0.799037  0.799159  0.799283
# 99999  0.466910  0.535399  0.571652    ...     0.801526  0.801643  0.801764
#
#            1993      1994      1995      1996      1997      1998      1999
# 99995  0.803137  0.803264  0.803390  0.803515  0.803642  0.803768  0.803889
# 99996  0.802823  0.802949  0.803076  0.803202  0.803327  0.803454  0.803580
# 99997  0.802511  0.802636  0.802762  0.802889  0.803015  0.803140  0.803266
# 99998  0.799410  0.799536  0.799660  0.799787  0.799913  0.800039  0.800164
# 99999  0.801889  0.802015  0.802141  0.802266  0.802392  0.802518  0.802644
#
# [5 rows x 1995 columns]

# %%
import talib.stream

upper, middle, lower = talib.stream.BBANDS(df['close'].values, timeperiod=minute)
(upper, middle, lower)
# Out:
# (7081.847207916341, 6992.295147573787, 6902.743087231233)

# %%
import talib.stream

def test():
    a = []
    close = df['close'].values
    for minute in range(5, 2000):
        upper, middle, lower = talib.stream.BBANDS(close, timeperiod=minute)
        a.append((close[-1] - lower) / (upper - lower))
    
    return a

# %timeit test()
# Out:
# 5.33 ms ± 221 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df['close'][-100:].plot()
bbr[-100:].plot(legend=False, colormap='hot')

# %%
length = 400
ax = bbr.loc[:, '10':'600':20][-length:].T.plot(colormap="YlOrRd", legend=False)
ax.axhline(y=0, color='b')

# %%
pandas.Series(talib.RSI(df['close'].values))[-100:].plot()

# %%
length = 1000
rsi = pandas.DataFrame()
for i in range(10, 100):
    rsi[str(i)] = talib.RSI(df['close'].values, timeperiod=i)


df['close'][-length:].plot()
rsi[-length:].plot(colormap='hot', legend=False)
bbr[-length:].plot(colormap='hot', legend=False)

# %%
rsi['10'][10]
# Out:
# 54.54545454545454

# %%
for i in range(10):
    print(df.close[i], rsi.loc[i].max(), bbr.loc[i].max())
# Out:
# 6134.5 nan nan
# 6132.0 nan nan
# 6129.0 nan nan
# 6127.5 nan nan
# 6127.5 nan 0.2632839616319739
# 6126.5 nan 0.24006237764963778
# 6126.5 nan 0.2815739858098506
# 6126.5 nan 0.30797615675917644
# 6138.5 nan 1.0990599914977428
# 6137.0 nan 0.8901300514959357

# %%
rsi.loc[100].idxmax(), rsi.loc[100].max()
# Out:
# ('24', 74.11445157683241)

# %%
def get_ratio(before, after):
    return 1 + (after - before) / before

get_ratio(100, 25)
# Out:
# 0.25

# %%
money = 100

order = []
for i in range(len(df.close)):
    _rsi = rsi['10'][i]
    price = df.close[i]
    
    if pandas.isna(_rsi):
        order.append((money, None, None, None, None, None))
        continue
    
    last_order = order[-1]
    last_money = last_order[0]
    last_pos = last_order[1]
    last_price = df.close[i-1]
    
    ratio = get_ratio(last_price, price)
    
    if _rsi < 20:
        
        if last_pos == None:
            order.append((last_money, 'buy', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), 'buy_sig'))
        else:
            order.append((last_money * ratio, last_pos, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
        
    elif _rsi > 90:
        
        if last_pos == 'buy':
            order.append((last_money * ratio, 'sell', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), 'sell_sig'))
        else:
            order.append((last_money, None, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
    
    else:
        if last_pos == 'buy':
            order.append((last_money * ratio, 'buy', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
        else:
            order.append((last_money, None, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))

# %%
money = [tup[0] for tup in order]
pos = [tup[1] for tup in order]
r = [tup[2] for tup in order]
r_max = [tup[3] for tup in order]
r_min = [tup[4] for tup in order]
sig = [tup[5] for tup in order]

len(money), len(pos), len(r)
backt = pandas.DataFrame({'money': money, 'pos': pos, 'r': r, 'r_max': r_max, 'r_min': r_min, 'sig': sig})

# %%
backt[:100]
# Out:
#     money   pos          r r_max r_min   sig
# 0   100.0  None        NaN  None  None  None
# 1   100.0  None        NaN  None  None  None
# 2   100.0  None        NaN  None  None  None
# 3   100.0  None        NaN  None  None  None
# 4   100.0  None        NaN  None  None  None
# 5   100.0  None        NaN  None  None  None
# 6   100.0  None        NaN  None  None  None
# 7   100.0  None        NaN  None  None  None
# 8   100.0  None        NaN  None  None  None
# 9   100.0  None        NaN  None  None  None
# 10  100.0  None  54.545455    10    10  None
# 11  100.0  None  54.545455    10    10  None
# 12  100.0  None  55.786026    10    12  None
# 13  100.0  None  54.144102    13    10  None
# 14  100.0  None  52.429509    14    10  None
# 15  100.0  None  52.429509    14    10  None
# 16  100.0  None  52.429509    15    10  None
# 17  100.0  None  52.429509    15    10  None
# 18  100.0  None  54.619821    10    18  None
# 19  100.0  None  51.961499    19    10  None
# 20  100.0  None  51.961499    20    10  None
# 21  100.0  None  54.684330    10    21  None
# 22  100.0  None  71.077599    10    22  None
# 23  100.0  None  68.038889    10    22  None
# 24  100.0  None  68.038889    10    22  None
# 25  100.0  None  68.038889    10    22  None
# 26  100.0  None  68.038889    10    22  None
# 27  100.0  None  56.913330    13    22  None
# 28  100.0  None  59.373741    10    22  None
# 29  100.0  None  59.373741    10    22  None
# ..    ...   ...        ...   ...   ...   ...
# 70  100.0  None  54.666943    30    10  None
# 71  100.0  None  56.828277    29    10  None
# 72  100.0  None  56.828277    29    10  None
# 73  100.0  None  56.828277    29    10  None
# 74  100.0  None  56.828277    29    10  None
# 75  100.0  None  56.828277    29    10  None
# 76  100.0  None  67.367431    10    76  None
# 77  100.0  None  72.883806    10    77  None
# 78  100.0  None  75.901399    10    78  None
# 79  100.0  None  75.901399    10    78  None
# 80  100.0  None  77.450414    10    80  None
# 81  100.0  None  84.214735    10    81  None
# 82  100.0  None  85.045474    10    82  None
# 83  100.0  None  76.140808    10    81  None
# 84  100.0  None  76.140808    10    81  None
# 85  100.0  None  71.518390    10    81  None
# 86  100.0  None  66.999023    13    80  None
# 87  100.0  None  62.603448    18    78  None
# 88  100.0  None  62.603448    18    78  None
# 89  100.0  None  62.603448    18    78  None
# 90  100.0  None  62.603448    18    78  None
# 91  100.0  None  62.603448    18    78  None
# 92  100.0  None  56.343400    27    10  None
# 93  100.0  None  73.805544    10    93  None
# 94  100.0  None  81.865218    10    94  None
# 95  100.0  None  98.111711    10    95  None
# 96  100.0  None  92.616807    10    95  None
# 97  100.0  None  80.388388    14    95  None
# 98  100.0  None  75.837049    18    95  None
# 99  100.0  None  84.842525    10    99  None
#
# [100 rows x 6 columns]

# %%
(
    len(backt[backt['pos'] == 'sell']),
    len(backt[backt['sig'] == 'buy_sig']), 
    len(backt[backt['sig'] == 'sell_sig']), 
    len(backt[backt['pos'] == 'buy']), 
    len(backt)
)
# Out:
# (157, 158, 157, 78905, 100000)

# %%
backt['money'].plot()

# %%
df['close'].plot()

# %%
backt['r_max'] = backt.r_max.fillna(0).astype(int)
backt['r_min'] = backt.r_min.fillna(0).astype(int)

# %%
backt[-200:].plot(y=['r_min'])

# %%
backt[-200:].plot(y=['r_max'])

# %%
backt[-200:].plot(y=['r_max', 'r_min'])

# %%
df.close[-200:].plot()

# %%
((rsi['10'][-200:] - 20) / 60).plot()

# %%
start = 10000
length = 100

bbr_half = bbr['20'] - 0.5
rsi_half = ((rsi['14'] - 20)/60) - 0.5

bbr_half[-start:-start+length].plot()
ax =  rsi_half[-start:-start+length].plot()
ax.axhline(y=0.5, color='r')
ax.axhline(y=-0.5, color='r')
ax.axhline(y=0, color='r')

# %%
ax = (bbr_half - rsi_half)[-start:-start+length].plot()
ax.axhline(y=0, color='r')

# %%
df.close[-start:-start+length].plot()

# %%
start = 600
length = 100
bbr.T.min()[-start:-start+length].plot()
bbr.T.max()[-start:-start+length].plot()

# %%
max_min = (bbr.T.max() - bbr.T.min())
ax = max_min[-start:-start+length].plot()
ax.axhline(y=1, color='r')

# %%
df['close'][-start:-start+length].plot()

# %%
(max_min[-start:-start+length] - max_min[-start:-start+length].shift()).plot()

# %% [markdown]
# BBW Count
# --------------

# %%
length = 200
bbr.loc[:, '20':'200':20][-length:].plot(colormap='hot')

# %%
df.close[-length:].plot()

# %%
bbr_max_id = bbr.T.idxmax().fillna(0).astype(int)
bbr_min_id = bbr.T.idxmin().fillna(0).astype(int)
bbr_max_id[-length:].plot()
bbr_min_id[-length:].plot()

# %%
bbr['20'][-length:].plot()
