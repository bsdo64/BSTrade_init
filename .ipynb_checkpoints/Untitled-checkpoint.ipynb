# %%
import time

import numpy

import pandas
import sqlite3
import ciso8601


def get_df(path=None):
    if path is None:
        path = ''

    conn = sqlite3.connect(path + "bitmex.db")
    c = conn.cursor()

    s = time.perf_counter()
    symbol = 'XBTUSD'
    count = 100000
    c.execute("SELECT * FROM tradebin1m"
              " ORDER BY timestamp"
              " LIMIT ?"
              " OFFSET (SELECT COUNT(*) FROM tradebin1m) - ?"
              , [count, count]
              )
    print('execute : ', (time.perf_counter() - s) / 1_000_000)

    s = time.perf_counter()
    d = c.fetchall()
    print('fetchall : ', (time.perf_counter() - s) / 1_000_000)

    ts = [ciso8601.parse_datetime(item[1]) for item in d]
    close = [item[6] for item in d]
    
    df = pandas.DataFrame({'close': close}, index=ts)
    return df

BS_PATH = '/Users/bsdo/projects/Python/BSTrade/BSTrade/Data/bitmex/'
df = get_df()
# Out:
# execute :  6.117579000419937e-08
# fetchall :  5.099456110037863e-07

# %%
import matplotlib
# %matplotlib inline
df['close'][-100:].plot()

# %%
import talib

# %%
talib.RSI?

# %%
df['rsi'] = talib.RSI(df['close'].values)

# %%
df[-500:].plot(y='rsi')

# %%
df['close_shift'] = df['close'] - df['close'].shift()
df['rsi_shift'] = df['rsi'] - df['rsi'].shift()

# %%
df
# Out:
#                             close        rsi  close_shift     rsi_shift
# 2018-06-24 18:33:00+00:00  6208.5        NaN          NaN           NaN
# 2018-06-24 18:34:00+00:00  6210.0        NaN          1.5           NaN
# 2018-06-24 18:35:00+00:00  6213.0        NaN          3.0           NaN
# 2018-06-24 18:36:00+00:00  6211.0        NaN         -2.0           NaN
# 2018-06-24 18:37:00+00:00  6197.5        NaN        -13.5           NaN
# 2018-06-24 18:38:00+00:00  6202.5        NaN          5.0           NaN
# 2018-06-24 18:39:00+00:00  6203.0        NaN          0.5           NaN
# 2018-06-24 18:40:00+00:00  6203.0        NaN          0.0           NaN
# 2018-06-24 18:41:00+00:00  6203.5        NaN          0.5           NaN
# 2018-06-24 18:42:00+00:00  6197.5        NaN         -6.0           NaN
# 2018-06-24 18:43:00+00:00  6204.0        NaN          6.5           NaN
# 2018-06-24 18:44:00+00:00  6200.0        NaN         -4.0           NaN
# 2018-06-24 18:45:00+00:00  6198.0        NaN         -2.0           NaN
# 2018-06-24 18:46:00+00:00  6197.5        NaN         -0.5           NaN
# 2018-06-24 18:47:00+00:00  6200.5  41.666667          3.0           NaN
# 2018-06-24 18:48:00+00:00  6199.5  40.752351         -1.0 -9.143156e-01
# 2018-06-24 18:49:00+00:00  6198.5  39.811543         -1.0 -9.408081e-01
# 2018-06-24 18:50:00+00:00  6203.0  45.867762          4.5  6.056219e+00
# 2018-06-24 18:51:00+00:00  6202.5  45.322079         -0.5 -5.456829e-01
# 2018-06-24 18:52:00+00:00  6196.0  38.851174         -6.5 -6.470904e+00
# 2018-06-24 18:53:00+00:00  6196.0  38.851174          0.0  7.105427e-15
# 2018-06-24 18:54:00+00:00  6196.0  38.851174          0.0 -1.421085e-14
# 2018-06-24 18:55:00+00:00  6195.5  38.325456         -0.5 -5.257184e-01
# 2018-06-24 18:56:00+00:00  6195.5  38.325456          0.0  0.000000e+00
# 2018-06-24 18:57:00+00:00  6200.0  45.958354          4.5  7.632898e+00
# 2018-06-24 18:58:00+00:00  6216.0  63.333953         16.0  1.737560e+01

# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %%
bbr.tail()
# Out:
#              20        40        60        80       100       120       140  \
# 99995  0.934435  0.849841  0.854839  0.766989  0.798499  0.824120  0.839099
# 99996  0.815979  0.763076  0.752984  0.724496  0.763513  0.794660  0.813526
# 99997  0.695666  0.662268  0.634318  0.672240  0.721898  0.758838  0.782754
# 99998  0.658180  0.654681  0.615370  0.657814  0.710216  0.749109  0.774218
# 99999  0.640897  0.660637  0.622464  0.653051  0.706238  0.745999  0.771238
#
#             160       180       200    ...         4800      4820      4840  \
# 99995  0.863349  0.881525  0.893845    ...     1.013935  1.014732  1.015742
# 99996  0.838339  0.858609  0.872245    ...     1.008700  1.009488  1.010471
# 99997  0.808690  0.831046  0.846499    ...     1.002246  1.003028  1.003976
# 99998  0.799859  0.822894  0.838737    ...     1.000715  1.001502  1.002422
# 99999  0.796210  0.819449  0.835571    ...     1.000413  1.001207  1.002104
#
#            4860      4880      4900      4920      4940      4960      4980
# 99995  1.016890  1.018060  1.019186  1.020308  1.021511  1.022755  1.023973
# 99996  1.011611  1.012769  1.013885  1.014995  1.016182  1.017418  1.018632
# 99997  1.005107  1.006250  1.007352  1.008449  1.009617  1.010844  1.012051
# 99998  1.003555  1.004693  1.005792  1.006885  1.008045  1.009271  1.010477
# 99999  1.003239  1.004376  1.005474  1.006565  1.007719  1.008948  1.010150
#
# [5 rows x 249 columns]

# %%
import talib.stream

upper, middle, lower = talib.stream.BBANDS(df['close'].values, timeperiod=minute)
(upper, middle, lower)
# Out:
# (7218.94097362017, 7018.993373493976, 6819.045773367782)

# %%
import talib.stream

def test():
    a = []
    close = df['close'].values
    for minute in range(5, 2000):
        upper, middle, lower = talib.stream.BBANDS(close, timeperiod=minute)
        a.append((close[-1] - lower) / (upper - lower))
    
    return a

# %timeit test()
# Out:
# 7.39 ms ± 200 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df['close'][-100:].plot()
bbr[-100:].plot(legend=False, colormap='hot')

# %%
length = 400
ax = bbr[-length:].T.plot(colormap="YlOrRd", legend=False)
ax.axhline(y=0, color='b')

# %%
pandas.Series(talib.RSI(df['close'].values))[-100:].plot()

# %%
length = 1000
rsi = pandas.DataFrame()
for i in range(10, 100):
    rsi[str(i)] = talib.RSI(df['close'].values, timeperiod=i)


df['close'][-length:].plot()
rsi[-length:].plot(colormap='hot', legend=False)
bbr[-length:].plot(colormap='hot', legend=False)

# %%
rsi['10'][10]
# Out:
# 44.15584415584416

# %%
for i in range(10):
    print(df.close[i], rsi.loc[i].max(), bbr.loc[i].max())
# Out:
# 6208.5 nan nan
# 6210.0 nan nan
# 6213.0 nan nan
# 6211.0 nan nan
# 6197.5 nan nan
# 6202.5 nan nan
# 6203.0 nan nan
# 6203.0 nan nan
# 6203.5 nan nan
# 6197.5 nan nan

# %%
rsi.loc[100].idxmax(), rsi.loc[100].max()
# Out:
# ('99', 43.93419067461743)

# %%
def get_ratio(before, after):
    return 1 + (after - before) / before

get_ratio(100, 25)
# Out:
# 0.25

# %%
money = 100

order = []
for i in range(len(df.close)):
    _rsi = rsi['10'][i]
    price = df.close[i]
    
    if pandas.isna(_rsi):
        order.append((money, None, None, None, None, None))
        continue
    
    last_order = order[-1]
    last_money = last_order[0]
    last_pos = last_order[1]
    last_price = df.close[i-1]
    
    ratio = get_ratio(last_price, price)
    
    if _rsi < 20:
        
        if last_pos == None:
            order.append((last_money, 'buy', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), 'buy_sig'))
        else:
            order.append((last_money * ratio, last_pos, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
        
    elif _rsi > 90:
        
        if last_pos == 'buy':
            order.append((last_money * ratio, 'sell', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), 'sell_sig'))
        else:
            order.append((last_money, None, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
    
    else:
        if last_pos == 'buy':
            order.append((last_money * ratio, 'buy', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
        else:
            order.append((last_money, None, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))

# %%
money = [tup[0] for tup in order]
pos = [tup[1] for tup in order]
r = [tup[2] for tup in order]
r_max = [tup[3] for tup in order]
r_min = [tup[4] for tup in order]
sig = [tup[5] for tup in order]

len(money), len(pos), len(r)
backt = pandas.DataFrame({'money': money, 'pos': pos, 'r': r, 'r_max': r_max, 'r_min': r_min, 'sig': sig})

# %%
backt[:100]
# Out:
#     money   pos          r r_max r_min   sig
# 0   100.0  None        NaN  None  None  None
# 1   100.0  None        NaN  None  None  None
# 2   100.0  None        NaN  None  None  None
# 3   100.0  None        NaN  None  None  None
# 4   100.0  None        NaN  None  None  None
# 5   100.0  None        NaN  None  None  None
# 6   100.0  None        NaN  None  None  None
# 7   100.0  None        NaN  None  None  None
# 8   100.0  None        NaN  None  None  None
# 9   100.0  None        NaN  None  None  None
# 10  100.0  None  44.155844    10    10  None
# 11  100.0  None  39.586028    11    10  None
# 12  100.0  None  37.433737    12    10  None
# 13  100.0  None  36.876795    13    10  None
# 14  100.0  None  42.572832    11    14  None
# 15  100.0  None  41.196018    11    14  None
# 16  100.0  None  39.767047    11    10  None
# 17  100.0  None  48.669572    10    17  None
# 18  100.0  None  47.797408    10    17  None
# 19  100.0  None  37.969221    19    10  None
# 20  100.0  None  37.969221    20    10  None
# 21  100.0  None  37.969221    20    10  None
# 22  100.0  None  37.162901    22    10  None
# 23  100.0  None  37.162901    23    10  None
# 24  100.0  None  49.159170    10    24  None
# 25  100.0  None  71.017899    10    25  None
# 26  100.0  None  52.865937    10    25  None
# 27  100.0  None  53.440835    10    25  None
# 28  100.0  None  53.440835    10    25  None
# 29  100.0  None  64.217252    10    29  None
# ..    ...   ...        ...   ...   ...   ...
# 70  100.0  None  68.179390    10    70  None
# 71  100.0  None  66.733626    10    69  None
# 72  100.0  None  66.733626    10    69  None
# 73  100.0  None  79.569936    10    73  None
# 74  100.0  None  79.569936    10    73  None
# 75  100.0  None  81.414458    10    75  None
# 76  100.0  None  83.108909    10    76  None
# 77  100.0  None  70.291837    10    73  None
# 78  100.0  None  48.245924    20    10  None
# 79  100.0  None  50.406242    18    73  None
# 80  100.0  None  44.858183    37    10  None
# 81  100.0  None  41.672900    40    10  None
# 82  100.0  None  39.789331    40    10  None
# 83  100.0  None  43.568088    38    10  None
# 84  100.0  None  42.100219    40    10  None
# 85  100.0  None  42.100219    40    10  None
# 86  100.0  None  47.553869    36    10  None
# 87  100.0  None  58.772263    10    87  None
# 88  100.0  None  28.780413    88    10  None
# 89  100.0  None  25.043599    89    10  None
# 90  100.0  None  31.014894    89    10  None
# 91  100.0  None  29.840950    89    10  None
# 92  100.0  None  28.928474    92    10  None
# 93  100.0  None  27.087827    93    10  None
# 94  100.0  None  40.993215    88    12  None
# 95  100.0  None  43.961898    88    15  None
# 96  100.0  None  41.198270    88    12  None
# 97  100.0  None  39.365188    88    10  None
# 98  100.0  None  37.510735    89    10  None
# 99  100.0  None  33.558472    99    10  None
#
# [100 rows x 6 columns]

# %%
(
    len(backt[backt['pos'] == 'sell']),
    len(backt[backt['sig'] == 'buy_sig']), 
    len(backt[backt['sig'] == 'sell_sig']), 
    len(backt[backt['pos'] == 'buy']), 
    len(backt)
)
# Out:
# (160, 161, 160, 78469, 100000)

# %%
backt['money'].plot()

# %%
df['close'].plot()

# %%
backt['r_max'] = backt.r_max.fillna(0).astype(int)
backt['r_min'] = backt.r_min.fillna(0).astype(int)

# %%
backt[-200:].plot(y=['r_min'])

# %%
backt[-200:].plot(y=['r_max'])

# %%
backt[-200:].plot(y=['r_max', 'r_min'])

# %%
df.close[-200:].plot()

# %%
((rsi['10'][-200:] - 20) / 60).plot()

# %%
start = 101
length = 100

bbr_half = bbr['20'] - 0.5
rsi_half = ((rsi['14'] - 20)/60) - 0.5

bbr_half[-start:-start+length].plot()
ax =  rsi_half[-start:-start+length].plot()
ax.axhline(y=0.5, color='r')
ax.axhline(y=-0.5, color='r')
ax.axhline(y=0, color='r')

# %%
ax = (bbr_half - rsi_half)[-start:-start+length].plot()
ax.axhline(y=0, color='r')

# %%
df.close[-start:-start+length].plot()

# %%
start = 600
length = 100
bbr.T.min()[-start:-start+length].plot()
bbr.T.max()[-start:-start+length].plot()

# %%
max_min = (bbr.T.max() - bbr.T.min())
ax = max_min[-start:-start+length].plot()
ax.axhline(y=1, color='r')

# %%
df['close'][-start:-start+length].plot()

# %%
(max_min[-start:-start+length] - max_min[-start:-start+length].shift()).plot()

# %% [markdown]
# BBW Count
# --------------

# %%
start = 2000
length = 1000
bbr[-start:-start+length].plot(colormap='hot')

# %%
start = 501
length = 500
df.close[-start:-start+length].plot()

# %%
bbr_max_id = bbr.T.idxmax().fillna(0).astype(int)
bbr_min_id = bbr.T.idxmin().fillna(0).astype(int)
bbr_max_id[-start:-start+length].plot()

# %%
bbr_max_id = bbr.T.idxmax().fillna(0).astype(int)
bbr_min_id = bbr.T.idxmin().fillna(0).astype(int)
bbr_max_id[-start:-start+length].plot()

# %%
bbr_min_id[-start:-start+length].plot()

# %%
bbr_min_id[-start:-start+length].plot()

# %%
ax = bbr[-10:].T.plot(colormap='GnBu', legend=False)
ax.axhline(y=0, color='r')
ax.axhline(y=1, color='r')

# %%
def get_bbr(r = range(20,5000,20)):
    bbr = pandas.DataFrame()
    close = df['close'].values
    for minute in r:
        period = minute
        upper, middle, lower = talib.BBANDS(close, timeperiod=period)
        bbr[str(period)] = (close - lower) / (upper - lower)
    return bbr

period = 1
minute = 20
four_times = 4 * 60 * (minute * period)
bbr = get_bbr(range(minute, four_times + 1, minute * period))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide

# %%
bbr.head()
# Out:
#    20  40  60  80  100  120  140  160  180  200  ...   4620  4640  4660  4680  \
# 0 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
# 1 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
# 2 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
# 3 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
# 4 NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...    NaN   NaN   NaN   NaN
#
#    4700  4720  4740  4760  4780  4800
# 0   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 240 columns]

# %%
df = get_df()
bbr = get_bbr(range(20, 8000, 20))
start = 2501
length = 500

df.close[-start:-start+length].plot(figsize=(15,5))
# Out:
# execute :  5.7221502007450907e-08
# fetchall :  5.15389556006994e-07
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide

# %%
bbr_max_id = bbr.T.idxmax().fillna(0).astype(int)
bbr_min_id = bbr.T.idxmin().fillna(0).astype(int)
df_bbr = pandas.DataFrame()
df_bbr['bbr_max'] = bbr_max_id[-start:-start+length]
df_bbr['bbr_min'] = bbr_min_id[-start:-start+length]
df_bbr.plot(figsize=(15,5), colormap='jet')

# %%
bbr['20'][-start:-start+length].plot(figsize=(15,5), colormap='Purples_r')

# %%
df_bbr.dtypes
# Out:
# bbr_max    int64
# bbr_min    int64
# dtype: object
