# %%
import time

import numpy

import pandas
import sqlite3
import ciso8601

conn = sqlite3.connect("bitmex.db")
c = conn.cursor()

s = time.perf_counter()
symbol = 'XBTUSD'
count = 100000
c.execute("SELECT * FROM tradebin1m"
          " ORDER BY timestamp"
          " LIMIT ?"
          " OFFSET (SELECT COUNT(*) FROM tradebin1m) - ?"
          , [count, count]
          )
print('execute : ', (time.perf_counter() - s) / 1000_000)

s = time.perf_counter()
d = c.fetchall()
print('fetchall : ', (time.perf_counter() - s) / 1000_000)

conn.close()
# Out:
# execute :  1.8232186620007269e-06
# fetchall :  1.0682835970073939e-06

# %%
ts = [ciso8601.parse_datetime(item[1]) for item in d]
close = [item[6] for item in d]

# %%
df = pandas.DataFrame({'close': close}, index=ts)

# %%
import matplotlib
# %matplotlib inline
df['close'][-100:].plot()

# %%
import talib

# %%
talib.RSI?

# %%
df['rsi'] = talib.RSI(df['close'].values)

# %%
df[-500:].plot(y='rsi')

# %%
df['close_shift'] = df['close'] - df['close'].shift()
df['rsi_shift'] = df['rsi'] - df['rsi'].shift()

# %%
df
# Out:
#                             close        rsi  close_shift     rsi_shift
# 2018-06-22 20:14:00+00:00  6158.0        NaN          NaN           NaN
# 2018-06-22 20:15:00+00:00  6146.5        NaN        -11.5           NaN
# 2018-06-22 20:16:00+00:00  6120.5        NaN        -26.0           NaN
# 2018-06-22 20:17:00+00:00  6099.5        NaN        -21.0           NaN
# 2018-06-22 20:18:00+00:00  6095.0        NaN         -4.5           NaN
# 2018-06-22 20:19:00+00:00  6095.5        NaN          0.5           NaN
# 2018-06-22 20:20:00+00:00  6109.0        NaN         13.5           NaN
# 2018-06-22 20:21:00+00:00  6113.0        NaN          4.0           NaN
# 2018-06-22 20:22:00+00:00  6096.5        NaN        -16.5           NaN
# 2018-06-22 20:23:00+00:00  6099.0        NaN          2.5           NaN
# 2018-06-22 20:24:00+00:00  6105.5        NaN          6.5           NaN
# 2018-06-22 20:25:00+00:00  6107.5        NaN          2.0           NaN
# 2018-06-22 20:26:00+00:00  6110.5        NaN          3.0           NaN
# 2018-06-22 20:27:00+00:00  6080.0        NaN        -30.5           NaN
# 2018-06-22 20:28:00+00:00  6068.0  20.779221        -12.0           NaN
# 2018-06-22 20:29:00+00:00  6009.0  14.710042        -59.0 -6.069178e+00
# 2018-06-22 20:30:00+00:00  6036.0  25.442267         27.0  1.073223e+01
# 2018-06-22 20:31:00+00:00  6023.5  23.940326        -12.5 -1.501941e+00
# 2018-06-22 20:32:00+00:00  6000.0  21.384461        -23.5 -2.555865e+00
# 2018-06-22 20:33:00+00:00  5990.0  20.387040        -10.0 -9.974217e-01
# 2018-06-22 20:34:00+00:00  5966.0  18.193738        -24.0 -2.193302e+00
# 2018-06-22 20:35:00+00:00  5975.0  21.599986          9.0  3.406248e+00
# 2018-06-22 20:36:00+00:00  5975.0  21.599986          0.0  0.000000e+00
# 2018-06-22 20:37:00+00:00  6042.0  42.331467         67.0  2.073148e+01
per, middle, lower = talib.BBANDS(df['close'].values, timeperiod=20)
bbr = (df['close'] - lower) / (upper - lower)

# %%
bbr = pandas.DataFrame()
for minute in range(5, 2000):
    upper, middle, lower = talib.BBANDS(df['close'].values, timeperiod=minute)
    bbr[str(minute)] = (df['close'].values - lower) / (upper - lower)
# Out:
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# /Users/bsdo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
bbr.tail()
# Out:
#               5         6         7         8         9        10        11  \
# 99995  0.753130  0.789076  0.805526  0.838836  0.690392  0.631064  0.578701
# 99996  0.710924  0.751285  0.785698  0.796946  0.826860  0.708953  0.655633
# 99997  0.573721  0.632068  0.675156  0.703433  0.723152  0.748665  0.658362
# 99998  0.005894  0.019238  0.272897  0.354690  0.365502  0.439710  0.458219
# 99999  0.195912  0.148965  0.139959  0.297740  0.365502  0.374211  0.442667
#
#              12        13        14    ...         1990      1991      1992  \
# 99995  0.536909  0.506506  0.484165    ...     0.631092  0.630821  0.630550
# 99996  0.605193  0.563657  0.533412    ...     0.633174  0.632915  0.632643
# 99997  0.613067  0.568931  0.531787    ...     0.631519  0.631264  0.631007
# 99998  0.419286  0.392214  0.368573    ...     0.620549  0.620272  0.620022
# 99999  0.460044  0.422761  0.396817    ...     0.620790  0.620512  0.620235
#
#            1993      1994      1995      1996      1997      1998      1999
# 99995  0.630286  0.630022  0.629777  0.629523  0.629292  0.629064  0.628844
# 99996  0.632372  0.632107  0.631842  0.631597  0.631343  0.631110  0.630882
# 99997  0.630736  0.630466  0.630202  0.629938  0.629694  0.629440  0.629208
# 99998  0.619769  0.619504  0.619239  0.618979  0.618721  0.618481  0.618231
# 99999  0.619985  0.619732  0.619467  0.619202  0.618943  0.618684  0.618444
#
# [5 rows x 1995 columns]

# %%
import talib.stream

upper, middle, lower = talib.stream.BBANDS(df['close'].values, timeperiod=minute)
(upper, middle, lower)
# Out:
# (7081.375412319668, 6947.220110055027, 6813.064807790387)

# %%
import talib.stream

def test():
    a = []
    for minute in range(5, 2000):
        upper, middle, lower = talib.stream.BBANDS(df['close'].values, timeperiod=minute)
        a.append((df['close'].values[-1] - lower) / (upper - lower))

# %timeit test()
# Out:
# 15.7 ms ± 325 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df['close'][-100:].plot()
bbr[-100:].plot(legend=False, colormap='hot')

# %%
length = 400
ax = bbr.loc[:, '10':'600':20][-length:].T.plot(colormap="YlOrRd", legend=False)
ax.axhline(y=0, color='b')

# %%
pandas.Series(talib.RSI(df['close'].values))[-100:].plot()

# %%
length = 1000
rsi = pandas.DataFrame()
for i in range(10, 100):
    rsi[str(i)] = talib.RSI(df['close'].values, timeperiod=i)


df['close'][-length:].plot()
rsi[-length:].plot(colormap='hot', legend=False)
bbr[-length:].plot(colormap='hot', legend=False)

# %%
rsi['10'][10]
# Out:
# 25.352112676056336

# %%
for i in range(10):
    print(df.close[i], rsi.loc[i].max(), bbr.loc[i].max())
# Out:
# 6158.0 nan nan
# 6146.5 nan nan
# 6120.5 nan nan
# 6099.5 nan nan
# 6095.0 nan 0.21056900578385282
# 6095.5 nan 0.3001578762360461
# 6109.0 nan 0.6314083879913036
# 6113.0 nan 0.8628435173238225
# 6096.5 nan 0.3264076277389333
# 6099.0 nan 0.42099001836749583

# %%
rsi.loc[100].idxmax(), rsi.loc[100].max()
# Out:
# ('10', 45.63010921422478)

# %%
def get_ratio(before, after):
    return 1 + (after - before) / before

get_ratio(100, 25)
# Out:
# 0.25

# %%
money = 100

order = []
for i in range(len(df.close)):
    _rsi = rsi['10'][i]
    price = df.close[i]
    
    if pandas.isna(_rsi):
        order.append((money, None, None, None, None, None))
        continue
    
    last_order = order[-1]
    last_money = last_order[0]
    last_pos = last_order[1]
    last_price = df.close[i-1]
    
    ratio = get_ratio(last_price, price)
    
    if _rsi < 20:
        
        if last_pos == None:
            order.append((last_money, 'buy', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), 'buy_sig'))
        else:
            order.append((last_money * ratio, last_pos, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
        
    elif _rsi > 90:
        
        if last_pos == 'buy':
            order.append((last_money * ratio, 'sell', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), 'sell_sig'))
        else:
            order.append((last_money, None, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
    
    else:
        if last_pos == 'buy':
            order.append((last_money * ratio, 'buy', _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))
        else:
            order.append((last_money, None, _rsi, rsi.loc[i].idxmax(), rsi.loc[i].idxmin(), None))

# %%
money = [tup[0] for tup in order]
pos = [tup[1] for tup in order]
r = [tup[2] for tup in order]
r_max = [tup[3] for tup in order]
r_min = [tup[4] for tup in order]
sig = [tup[5] for tup in order]

len(money), len(pos), len(r)
backt = pandas.DataFrame({'money': money, 'pos': pos, 'r': r, 'r_max': r_max, 'r_min': r_min, 'sig': sig})

# %%
backt[:100]
# Out:
#          money   pos          r r_max r_min      sig
# 0   100.000000  None        NaN  None  None     None
# 1   100.000000  None        NaN  None  None     None
# 2   100.000000  None        NaN  None  None     None
# 3   100.000000  None        NaN  None  None     None
# 4   100.000000  None        NaN  None  None     None
# 5   100.000000  None        NaN  None  None     None
# 6   100.000000  None        NaN  None  None     None
# 7   100.000000  None        NaN  None  None     None
# 8   100.000000  None        NaN  None  None     None
# 9   100.000000  None        NaN  None  None     None
# 10  100.000000  None  25.352113    10    10     None
# 11  100.000000  None  26.877874    10    11     None
# 12  100.000000  None  29.286773    10    12     None
# 13  100.000000  None  21.343874    13    10     None
# 14  100.000000   buy  19.081525    14    10  buy_sig
# 15   99.027686   buy  12.084196    15    10     None
# 16   99.472643   buy  25.900818    10    16     None
# 17   99.266645   buy  23.963549    13    16     None
# 18   98.879367   buy  20.725415    14    10     None
# 19   98.714568   buy  19.480786    19    10     None
# 20   98.319051   buy  16.791725    20    10     None
# 21   98.467370   buy  21.317186    13    16     None
# 22   98.467370   buy  21.317186    13    16     None
# 23   99.571523   buy  47.539701    10    23     None
# 24   99.406724   buy  45.049866    10    23     None
# 25   99.027686   buy  39.731972    10    23     None
# 26   99.241925   buy  43.891534    10    26     None
# 27   99.143045   buy  42.391154    10    26     None
# 28  100.140079   buy  58.344570    10    28     None
# 29   99.596243   buy  49.959633    10    28     None
# ..         ...   ...        ...   ...   ...      ...
# 70   99.118326   buy  63.858918    10    70     None
# 71   98.648649   buy  51.386301    10    68     None
# 72   98.772248   buy  54.012626    10    68     None
# 73   98.862887   buy  55.951630    10    73     None
# 74   98.912327   buy  57.049188    10    74     None
# 75   98.640409   buy  49.510209    10    68     None
# 76   98.574489   buy  47.808438    12    68     None
# 77   98.434410   buy  44.219724    15    68     None
# 78   98.623929   buy  49.875834    10    68     None
# 79   98.648649   buy  50.601772    10    68     None
# 80   98.739288   buy  53.354067    10    80     None
# 81   98.928807   buy  58.700031    10    81     None
# 82   98.945287   buy  59.152344    10    82     None
# 83   99.044166   buy  61.931804    10    83     None
# 84   99.044166   buy  61.931804    10    83     None
# 85   99.208965   buy  66.607118    10    85     None
# 86   99.118326   buy  61.957049    10    85     None
# 87   99.068886   buy  59.441990    10    85     None
# 88   98.978247   buy  54.902099    10    83     None
# 89   98.978247   buy  54.902099    10    83     None
# 90   98.788728   buy  45.860575    16    81     None
# 91   98.590969   buy  38.507928    21    10     None
# 92   98.689848   buy  43.537083    18    81     None
# 93   98.648649   buy  41.948752    20    10     None
# 94   98.689848   buy  44.210237    18    81     None
# 95   98.442650   buy  35.095528    27    10     None
# 96   98.253131   buy  29.852679    49    10     None
# 97   97.404417   buy  17.123927    97    10     None
# 98   98.005933   buy  37.956465    46    10     None
# 99   98.071852   buy  39.799105    31    10     None
#
# [100 rows x 6 columns]

# %%
(
    len(backt[backt['pos'] == 'sell']),
    len(backt[backt['sig'] == 'buy_sig']), 
    len(backt[backt['sig'] == 'sell_sig']), 
    len(backt[backt['pos'] == 'buy']), 
    len(backt)
)
# Out:
# (159, 160, 159, 78636, 100000)

# %%
backt['money'].plot()

# %%
df['close'].plot()

# %%
backt['r_max'] = backt.r_max.fillna(0).astype(int)
backt['r_min'] = backt.r_min.fillna(0).astype(int)

# %%
backt[-200:].plot(y=['r_min'])

# %%
backt[-200:].plot(y=['r_max'])

# %%
backt[-200:].plot(y=['r_max', 'r_min'])

# %%
df.close[-200:].plot()

# %%
((rsi['10'][-200:] - 20) / 60).plot()

# %%
start = 1000
length = 500
((rsi['10'][-start:-start+length] - 20) / 60).plot()
ax =  bbr['20'][-start:-start+length].plot()
ax.axhline(y=1, color='r')
ax.axhline(y=0, color='r')

# %%
df.close[-start:-start+length].plot()

# %%
pandas.Series(money[-200:]).plot()

# %%
start = 600
length = 100
bbr.T.min()[-start:-start+length].plot()
bbr.T.max()[-start:-start+length].plot()

# %%
max_min = (bbr.T.max() - bbr.T.min())
ax = max_min[-start:-start+length].plot()
ax.axhline(y=1, color='r')

# %%
df['close'][-start:-start+length].plot()

# %%
(max_min[-start:-start+length] - max_min[-start:-start+length].shift()).plot()
